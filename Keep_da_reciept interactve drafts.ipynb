# %%
import pandas as pd
import csv
df = pd.read_csv(r'C:\Users\shede\Keep_da_reciept.py\plan.ipynb-Keep_da_reciept.py\ASSETTS 2\pay_CASH.csv')
print(df.head())

df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
CASH_Pay = df[(df['PAYMENT METHOD'] == 'CASH')]
CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(CASH_Pay.head())

print(CASH_total)
# Out:
#    Unnamed: 0      STORE NAME  STORE NUMBER        DATE AMOUNTS PAID  \
# 0           3  DOLLAR General         15064  12/21/2022       $1.06
# 1           6  DOLLAR General         15064  10/30/2022      $30.35
# 2           7  DOLLAR General         15064  10/26/2022       $5.30
# 3           8  DOLLAR General         15064   9/27/2022       $1.85
# 4           9  DOLLAR General         15064  10/22/2022      $24.18
#
#   PAYMENT METHOD   PURCHASE TYPE     STATE
# 0           CASH  KITCHEN SUPPLY  KENTUCKY
# 1           CASH  KITCHEN SUPPLY  KENTUCKY
# 2           CASH        MEDICINE  KENTUCKY
# 3           CASH            FOOD  KENTUCKY
# 4           CASH     KIDS SUPPLY  KENTUCKY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 df = pd.read_csv(r'C:\Users\shede\Keep_da_reciept.py\plan.ipynb-Keep_da_reciept.py\ASSETTS 2\pay_CASH.csv')
#       4 print(df.head())
# ----> 6 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       7 CASH_Pay = df[(df['PAYMENT METHOD'] == 'CASH')]
#       8 CASH_total = sum(CASH_Pay['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '12/21/2022'

# %%
import pandas as pd
import csv
df = pd.read_csv(r'C:\Users\shede\Keep_da_reciept.py\plan.ipynb-Keep_da_reciept.py\ASSETTS 2\pay_CASH.csv')
print(df.head())

df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)

CASH_Pay = df[(df['PAYMENT METHOD'] == 'CASH')]

CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(CASH_Pay.head())

print(CASH_total)
# Out:
#    Unnamed: 0      STORE NAME  STORE NUMBER        DATE AMOUNTS PAID  \
# 0           3  DOLLAR General         15064  12/21/2022       $1.06
# 1           6  DOLLAR General         15064  10/30/2022      $30.35
# 2           7  DOLLAR General         15064  10/26/2022       $5.30
# 3           8  DOLLAR General         15064   9/27/2022       $1.85
# 4           9  DOLLAR General         15064  10/22/2022      $24.18
#
#   PAYMENT METHOD   PURCHASE TYPE     STATE
# 0           CASH  KITCHEN SUPPLY  KENTUCKY
# 1           CASH  KITCHEN SUPPLY  KENTUCKY
# 2           CASH        MEDICINE  KENTUCKY
# 3           CASH            FOOD  KENTUCKY
# 4           CASH     KIDS SUPPLY  KENTUCKY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 df = pd.read_csv(r'C:\Users\shede\Keep_da_reciept.py\plan.ipynb-Keep_da_reciept.py\ASSETTS 2\pay_CASH.csv')
#       4 print(df.head())
# ----> 6 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       8 CASH_Pay = df[(df['PAYMENT METHOD'] == 'CASH')]
#      10 CASH_total = sum(CASH_Pay['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '12/21/2022'

# %%
import csv
import pandas as pd
import matplotlib as plt

# %%
import numpy as np

# %%
df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(df['AMOUNTS PAID'])

print(total)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
#       2 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       3 total = sum(df['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FAMILY FINANCES SINCE 0801222.csv'

# %%
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]

# %%
import pandas as pd
df= pd.read_csv

# %%
import pandas as pd
df= pd.read_csv("pay_CASH")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 df= pd.read_csv("pay_CASH")
#       3 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pay_CASH'

# %%
import pandas as pd
df= pd.read_csv("pay_CASH")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pd
# ----> 2 df= pd.read_csv("pay_CASH")
#       3 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pay_CASH'

# %%
import pandas as pd
df= pd.read_csv("FAMILY FINANCES SINCE 0801222.CSV")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 df= pd.read_csv("FAMILY FINANCES SINCE 0801222.CSV")
#       3 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FAMILY FINANCES SINCE 0801222.CSV'

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(df['AMOUNTS PAID'])

print(total)

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

data = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])

import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()

import csv
import pandas as pd
df = pd.read_csv('pay_CASH.csv')
print(df)



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
# wal total
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 5
#       2 import pandas as pd
#       3 import matplotlib as plt
# ----> 5 df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
#       6 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       7 total = sum(df['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FAMILY FINANCES SINCE 0801222.csv'

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(df['AMOUNTS PAID'])
print (total)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       2 import pandas as pd
#       3 import matplotlib as plt
# ----> 5 df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
#       6 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       7 total = sum(df['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FAMILY FINANCES SINCE 0801222.csv'

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])

# %%
print('data')
# Out:
# data

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)
# Out:
# 2699.36

# %%
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)
# Out:
# 1345.7199999999998

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

DOLLAR_General_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOG_total = sum(DOLLAR_General_data['AMOUNTS PAID'])
print(DOG_total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       4 DOLLAR_General_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
# ----> 5 DOG_total = sum(DOLLAR_General_data['AMOUNTS PAID'])
#       6 print(DOG_total)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

DOLLAR_General_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DG_total = sum(DOLLAR_General_data['AMOUNTS PAID'])
print(DG_total)
# Out:
# 2699.36
# 467.56000000000006

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

DOLLAR_General_data = data.loc[(data['PAYMENT METHOD'] == 'DOLLAR General')]
DG_total = sum(DOLLAR_General_data['AMOUNTS PAID'])
print(DG_total)
# Out:
# 2699.36
# 0

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

DOH_data = data.loc[(data['STORE NAME'] == 'DOLLAR General', 'HIBETTS')]
DG_total = sum(DOH_data['AMOUNTS PAID'])
print(DG_total)
# Out:
# 2699.36
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HIBETTS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 8
#       5 total = sum(data['AMOUNTS PAID'])
#       6 print(total)
# ----> 8 DOH_data = data.loc[(data['STORE NAME'] == 'DOLLAR General', 'HIBETTS')]
#       9 DG_total = sum(DOH_data['AMOUNTS PAID'])
#      10 print(DG_total)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1064'>1065</a>     if self._is_scalar_access(key):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1065'>1066</a>         return self.obj._get_value(*key, takeable=self._takeable)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1066'>1067</a>     return self._getitem_tuple(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1067'>1068</a> else:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1068'>1069</a>     # we by definition only have the 0th axis
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1069'>1070</a>     axis = self.axis or 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1244'>1245</a> with suppress(IndexingError):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1245'>1246</a>     tup = self._expand_ellipsis(tup)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1246'>1247</a>     return self._getitem_lowerdim(tup)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1248'>1249</a> # no multi-index, so validate all of the indexers
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1249'>1250</a> tup = self._validate_tuple_indexer(tup)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:967, in _LocationIndexer._getitem_lowerdim(self, tup)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=962'>963</a> for i, key in enumerate(tup):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=963'>964</a>     if is_label_like(key):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=964'>965</a>         # We don't need to check for tuples here because those are
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=965'>966</a>         #  caught by the _is_nested_tuple_indexer check above.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=966'>967</a>         section = self._getitem_axis(key, axis=i)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=968'>969</a>         # We should never have a scalar section here, because
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=969'>970</a>         #  _getitem_lowerdim is only called after a check for
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=970'>971</a>         #  is_scalar_access, which that would be.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=971'>972</a>         if section.ndim == self.ndim:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=972'>973</a>             # we're in the middle of slicing through a MultiIndex
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=973'>974</a>             # revise the key wrt to `section` by inserting an _NS
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1309'>1310</a> # fall thru to straight lookup
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1310'>1311</a> self._validate_key(key, axis)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1311'>1312</a> return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1257'>1258</a> def _get_label(self, label, axis: int):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1258'>1259</a>     # GH#5567 this will fail if the label is not present in the axis.
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexing.py?line=1259'>1260</a>     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4041, in NDFrame.xs(self, key, axis, level, drop_level)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/generic.py?line=4038'>4039</a> if axis == 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/generic.py?line=4039'>4040</a>     if drop_level:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/generic.py?line=4040'>4041</a>         return self[key]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/generic.py?line=4041'>4042</a>     index = self.columns
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/generic.py?line=4042'>4043</a> else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'HIBETTS'

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

DOLLAR_General_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DG_total = sum(DOLLAR_General_data['AMOUNTS PAID'])
print(DG_total)
# Out:
# 2699.36
# 467.56000000000006

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(df['AMOUNTS PAID'])

print(total)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 5
#       2 import pandas as pd
#       3 import matplotlib as plt
# ----> 5 df = pd.read_csv('FAMILY FINANCES SINCE 0801222.csv')
#       6 df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
#       7 total = sum(df['AMOUNTS PAID'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FAMILY FINANCES SINCE 0801222.csv'

# %%
import csv
import pandas as pd
df = pd.read_csv('pay_CASH.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 3
#       1 import csv
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('pay_CASH.csv')
#       4 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pay_CASH.csv'

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1345.7199999999998

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1345.7199999999998

# %%
import pandas as pd
import numpy
import csv
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


df = pd.read_csv('pay_EBT.csv')

print(df)
import matplotlib.pyplot as plt
import numpy as np

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 7
#       3 import csv
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
# ----> 7 df = pd.read_csv('pay_EBT.csv')
#       9 print(df)
#      10 import matplotlib.pyplot as plt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pay_EBT.csv'

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))


import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5
# 1345.7199999999998

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))


import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5
# 1345.7199999999998

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))
print(pay_EBT)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# 5   DOLLAR General         15064  12/29/2022      $17.95             EBT
# 11  DOLLAR General         15064   1/19/2023      $11.45             EBT
# 12  DOLLAR General         15064   2/17/2023      $67.75             EBT
# 13  DOLLAR General         15064   1/19/2023       $3.00             EBT
# 14  DOLLAR General          2840    2/2/2023       $1.82             EBT
# 18  DOLLAR General         15064   1/10/2022      $10.10             EBT
# 20  DOLLAR General         15064  10/30/2022       $3.70             EBT
# 22  DOLLAR General         15064  10/30/2022       $7.05             EBT
# 23  DOLLAR General         15064   10/2/2022       $4.35             EBT
# 25  DOLLAR General         15064   1/21/2023     $128.70             EBT
# 30     DOLLAR TREE          5648  11/19/2022       $5.00             EBT
# 32   FAMILY DOLLAR          3264  11/29/2022       $8.75             EBT
# 33       FOOD CITY           424   12/2/2022      $51.29             EBT
# 34       FOOD CITY           424   2/17/2023      $65.97             EBT
# 46       SAVE ALOT         23488  11/29/2022      $23.10             EBT
# 47       SAVE ALOT         23488    2/2/2023      $45.30             EBT
# 57         WALMART          1233  10/19/2022      $23.20             EBT
# 59         WALMART          1233    1/5/2023      $30.35             EBT
# 62         WALMART          1233  10/12/2022      $35.54             EBT
# 63         WALMART          1233  10/24/2022      $25.38             EBT
# 65         WALMART          1233  10/16/2022     $365.54             EBT
# 67         WALMART          1233   2/17/2023     $157.48             EBT
# 68         WALMART          1233   2/17/2023       $3.48             EBT
# 69         WALMART          1233  10/26/2022      $67.94             EBT
# 71         WALMART          1233  11/18/2022      $76.96             EBT
# 75         WALMART          1233  11/19/2022       $9.25             EBT
#
#    PURCHASE TYPE     STATE
# 0           FOOD  KENTUCKY
# 1           FOOD  KENTUCKY
# 2           FOOD  KENTUCKY
# 4           FOOD  KENTUCKY
# 5           FOOD  KENTUCKY
# 11          FOOD  KENTUCKY
# 12          FOOD  KENTUCKY
# 13          FOOD  KENTUCKY
# 14          FOOD  KENTUCKY
# 18          FOOD  KENTUCKY
# 20          FOOD  KENTUCKY
# 22          FOOD  KENTUCKY
# 23          FOOD  KENTUCKY
# 25          FOOD  KENTUCKY
# 30          FOOD  KENTUCKY
# 32          FOOD  KENTUCKY
# 33          FOOD  KENTUCKY
# 34          FOOD  KENTUCKY
# 46          FOOD  KENTUCKY
# 47          FOOD  KENTUCKY
# 57          FOOD  KENTUCKY
# 59          FOOD  KENTUCKY
# 62          FOOD  KENTUCKY
# 63          FOOD  KENTUCKY
# 65          FOOD  KENTUCKY
# 67          FOOD  KENTUCKY
# 68          FOOD  KENTUCKY
# 69          FOOD  KENTUCKY
# 71          FOOD  KENTUCKY
# 75          FOOD  KENTUCKY

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

df = pd.read_csv(' add csv file here')
print(df)

pay_ebt = df[(df['payment method'] == 'ebt')]
print(len(pay_ebt))

pay_cash = df[(df['payment method'] == 'cash')] 
print(len(pay_cash))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 7
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       5 print(df)
# ----> 7 df = pd.read_csv(' add csv file here')
#       8 print(df)
#      10 pay_ebt = df[(df['payment method'] == 'ebt')]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=208'>209</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=209'>210</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=210'>211</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=328'>329</a>         stacklevel=find_stack_level(),
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=329'>330</a>     )
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/util/_decorators.py?line=330'>331</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=934'>935</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=935'>936</a>     dialect,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=936'>937</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=945'>946</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=946'>947</a> )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=947'>948</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=949'>950</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=601'>602</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=603'>604</a> # Create the parser.
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=604'>605</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=606'>607</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=607'>608</a>     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1438'>1439</a>     self.options["has_index_names"] = kwds["has_index_names"]
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1440'>1441</a> self.handles: IOHandles | None = None
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1441'>1442</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1732'>1733</a>     if "b" not in mode:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1733'>1734</a>         mode += "b"
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1734'>1735</a> self.handles = get_handle(
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1735'>1736</a>     f,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1736'>1737</a>     mode,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1737'>1738</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1738'>1739</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1739'>1740</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1740'>1741</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1741'>1742</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1742'>1743</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1743'>1744</a> )
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1744'>1745</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/parsers/readers.py?line=1745'>1746</a> f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=850'>851</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=851'>852</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=852'>853</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=853'>854</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=854'>855</a>         # Encoding
# --> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=855'>856</a>         handle = open(
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=856'>857</a>             handle,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=857'>858</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=858'>859</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=859'>860</a>             errors=errors,
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=860'>861</a>             newline="",
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=861'>862</a>         )
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=862'>863</a>     else:
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=863'>864</a>         # Binary mode
#     <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/io/common.py?line=864'>865</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: ' add csv file here'

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_ebt = df[(df['payment method'] == 'ebt')]
print(len(pay_ebt))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment method'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 8
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       5 print(df)
# ----> 8 pay_ebt = df[(df['payment method'] == 'ebt')]
#       9 print(len(pay_ebt))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'payment method'

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)



df = df[(df['payment method'] == 'ebt')]
print(len(df))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment method'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 9
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       5 print(df)
# ----> 9 df = df[(df['payment method'] == 'ebt')]
#      10 print(len(df))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'payment method'

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


EBT = df[(df['payment method'] == 'ebt')]
print(len(EBT))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment method'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 8
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       5 print(df)
# ----> 8 EBT = df[(df['payment method'] == 'ebt')]
#       9 print(len(EBT))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'payment method'

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_ebt = df[(df['payment method'] == 'EBT')]
print(len(pay_ebt))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment method'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 8
#       4 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       5 print(df)
# ----> 8 pay_ebt = df[(df['payment method'] == 'EBT')]
#       9 print(len(pay_ebt))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'payment method'

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_ebt = df[(df['PAYMENT METHOD'] == 'ebt')]
print(len(pay_ebt))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 0

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_ebt = df[(df['PAYMENT METHOD'] == 'EBT')]
print(len(pay_ebt))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 30

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_cash = df[(df['PAYMENT METHOD'] == 'CASH')]
print(len(pay_cash))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 51

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_cash = df[(df['PAYMENT METHOD'] == 'CASH')]
print(pay_cash)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 6   DOLLAR General         15064  10/30/2022      $30.35            CASH
# 7   DOLLAR General         15064  10/26/2022       $5.30            CASH
# 8   DOLLAR General         15064   9/27/2022       $1.85            CASH
# 9   DOLLAR General         15064  10/22/2022      $24.18            CASH
# 10  DOLLAR General         15064  10/21/2022       $2.12            CASH
# 15  DOLLAR General          2840    2/2/2023       $0.25            CASH
# 16  DOLLAR General         15064   1/11/2023      $46.99            CASH
# 17  DOLLAR General         15064    2/2/2023       $6.00            CASH
# 19  DOLLAR General         15064  10/16/2022       $8.22            CASH
# 38         APPERAL   KENTUCKY
# 39    HOUSE SUPPLY   KENTUCKY
# 40    HOUSE SUPPLY   KENTUCKY
# 41    HOUSE SUPPLY   KENTUCKY
# 42      CIGARETTES   KENTUCKY
# 43            FOOD   KENTUCKY
# 44     WIRE TO RAY   KENTUCKY
# 45     WIRE TO RAY   KENTUCKY
# 48          LIQUOR  LOUISIANA
# 49             GAS   KENTUCKY
# 50             GAS  LOUISIANA
# 51      CIGARETTES   KENTUCKY
# 52             GAS   KENTUCKY
# 53      CIGARETTES   KENTUCKY
# 54             gaS   KENTUCKY
# 55      CIGARETTES   KENTUCKY
# 56            FOOD   KENTUCKY
# 58        SIR TOYS   KENTUCKY
# 60         APPERAL   KENTUCKY
# 61         APPERAL   KENTUCKY
# 64         APPERAL   KENTUCKY
# 66  KITCHEN SUPPLY   KENTUCKY
# 70    HOUSE SUPPLY   KENTUCKY
# 72    HOUSE SUPPLY   KENTUCKY
# 73     WIRE TO RAY   KENTUCKY
# 74    HOUSE SUPPLY   KENTUCKY
# 76         APPERAL   KENTUCKY
# 77     WIRE TO RAY   KENTUCKY
# 78            FOOD   KENTUCKY
# 79    HOUSE SUPPLY   KENTUCKY
# 80            FOOD   KENTUCKY

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_ebt = df[(df['PAYMENT METHOD'] == 'EBT')]
print(len(pay_ebt))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 30

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_cash = df[(df['PAYMENT METHOD'] == 'CASH')]
print(pay_cash)
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 6   DOLLAR General         15064  10/30/2022      $30.35            CASH
# 7   DOLLAR General         15064  10/26/2022       $5.30            CASH
# 8   DOLLAR General         15064   9/27/2022       $1.85            CASH
# 9   DOLLAR General         15064  10/22/2022      $24.18            CASH
# 10  DOLLAR General         15064  10/21/2022       $2.12            CASH
# 15  DOLLAR General          2840    2/2/2023       $0.25            CASH
# 16  DOLLAR General         15064   1/11/2023      $46.99            CASH
# 17  DOLLAR General         15064    2/2/2023       $6.00            CASH
# 19  DOLLAR General         15064  10/16/2022       $8.22            CASH
# 21  DOLLAR General         15064  10/30/2022      $14.47            CASH
# 24  DOLLAR General         15064   10/2/2022       $1.10            CASH
# 26  DOLLAR General         15064   1/11/2023       $7.25            CASH
# 27     DOLLAR TREE          5648  11/16/2022      $13.25            CASH
# 28     DOLLAR TREE          5648  10/21/2022      $15.87            CASH
# 29     DOLLAR TREE          5648  11/19/2022      $14.14            CASH
# 31     DOUBLE KWIK          2076   8/29/2022      $10.00            CASH
# 35       GOOD WILL         63294  10/21/2022      $13.16            CASH
# 36   GULF FRANKLIN        205538   1/19/2023       $5.43            CASH
# 37        HIBBETTS          1118  11/25/2022      $31.80            CASH
# 38        HIBBETTS          1118  11/25/2022     $135.62            CASH
# 39           LOWES          1797   1/13/2023      $15.24            CASH
# 40           LOWES          1797   11/2/2022      $12.08            CASH
# 41           LOWES          1797  11/23/2022      $17.14            CASH
# 42  MARTIN TABACCO            16   8/13/2022       $5.34            CASH
# 43      MC DONALDS          5011   8/12/2022      $15.23            CASH
# 44      MONEY GRAM          1233   11/7/2022      $54.00            CASH
# 45      MONEY GRAM          1233  10/12/2022      $45.00            CASH
# 48       SIMONEADS           139   1/17/2023      $29.09            CASH
# 49        SPEEDWAY          9538   1/13/2023      $85.00            CASH
# 50      THE MOBILE        205520   1/17/2023      $62.02            CASH
# 51        VIP FUEL        131987   1/19/2022      $21.29            CASH
# 52        VIP FUEL        131987   1/12/2023      $20.00            CASH
# 53        VIP FUEL        131987   1/12/2023       $4.23            CASH
# 54        VIP FUEL             2   1/21/2023      $10.00            CASH
# 55        VIP FUEL             2   1/21/2023       $4.23            CASH
# 56         WALMART          1233   11/9/2022      $17.96            CASH
# 58         WALMART          1233  10/21/2022      $24.35            CASH
# 60         WALMART          1233  10/21/2022      $96.96            CASH
# 61         WALMART          1233  10/17/2022      $33.47            CASH
# 64         WALMART          1233  10/24/2022      $20.00            CASH
# 66         WALMART          1233  10/16/2022      $47.42            CASH
# 70         WALMART          1233  10/26/2022      $13.79            CASH
# 72         WALMART          1233  11/18/2022      $11.05            CASH
# 73         WALMART           696   9/12/2022      $44.00            CASH
# 74         WALMART          1233  11/25/2022     $120.56            CASH
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE      STATE
# 3   KITCHEN SUPPLY   KENTUCKY
# 6   KITCHEN SUPPLY   KENTUCKY
# 7         MEDICINE   KENTUCKY
# 8             FOOD   KENTUCKY
# 9      KIDS SUPPLY   KENTUCKY
# 10    HOUSE SUPPLY   KENTUCKY
# 15            FOOD   KENTUCKY
# 16            FOOD   KENTUCKY
# 17    HOUSE SUPPLY   KENTUCKY
# 19      MOM SUPPLY   KENTUCKY
# 21    HOUSE SUPPLY   KENTUCKY
# 24    HOUSE SUPPLY   KENTUCKY
# 26            FOOD   KENTUCKY
# 27  KITCHEN SUPPLY   KENTUCKY
# 28     GIFT KATLIN   KENTUCKY
# 29    HOUSE SUPPLY   KENTUCKY
# 31             gaS   KENTUCKY
# 35         APPERAL   KENTUCKY
# 36      CIGARETTES  LOUISIANA
# 37         APPERAL   KENTUCKY
# 38         APPERAL   KENTUCKY
# 39    HOUSE SUPPLY   KENTUCKY
# 40    HOUSE SUPPLY   KENTUCKY
# 41    HOUSE SUPPLY   KENTUCKY
# 42      CIGARETTES   KENTUCKY
# 43            FOOD   KENTUCKY
# 44     WIRE TO RAY   KENTUCKY
# 45     WIRE TO RAY   KENTUCKY
# 48          LIQUOR  LOUISIANA
# 49             GAS   KENTUCKY
# 50             GAS  LOUISIANA
# 51      CIGARETTES   KENTUCKY
# 52             GAS   KENTUCKY
# 53      CIGARETTES   KENTUCKY
# 54             gaS   KENTUCKY
# 55      CIGARETTES   KENTUCKY
# 56            FOOD   KENTUCKY
# 58        SIR TOYS   KENTUCKY
# 60         APPERAL   KENTUCKY
# 61         APPERAL   KENTUCKY
# 64         APPERAL   KENTUCKY
# 66  KITCHEN SUPPLY   KENTUCKY
# 70    HOUSE SUPPLY   KENTUCKY
# 72    HOUSE SUPPLY   KENTUCKY
# 73     WIRE TO RAY   KENTUCKY
# 74    HOUSE SUPPLY   KENTUCKY
# 76         APPERAL   KENTUCKY
# 77     WIRE TO RAY   KENTUCKY
# 78            FOOD   KENTUCKY
# 79    HOUSE SUPPLY   KENTUCKY
# 80            FOOD   KENTUCKY

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_cash = df[(df['PAYMENT METHOD'] == 'CASH')]
print(len(pay_cash.head()))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_ebt = df[(df['payment method'] == 'ebt')]
print(len(pay_ebt))

pay_cash = df[(df['payment method'] == 'cash')] 
print(len(pay_cash))
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment method'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 6
#       3 df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
#       4 print(df)
# ----> 6 pay_ebt = df[(df['payment method'] == 'ebt')]
#       7 print(len(pay_ebt))
#       9 pay_cash = df[(df['payment method'] == 'cash')]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/shede/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'payment method'

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)


pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))
print(df)


import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1345.7199999999998

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)





import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()

pay_EBT = df[(df['PAYMENT METHOD'] =="EBT")]
print(len(pay_EBT.head()))
print(df)



import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 5
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1345.7199999999998

# %%
import csv
import pandas as pd
import matplotlib as plt

df = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(df)

pay_Ebt =df[(df["PAYMENT METHOD"] == 'EBT')]
print(pay_Ebt)


import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()




import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
df[df.columns[3]] = df[df.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = df.loc[(df['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# 5   DOLLAR General         15064  12/29/2022      $17.95             EBT
# 11  DOLLAR General         15064   1/19/2023      $11.45             EBT
# 12  DOLLAR General         15064   2/17/2023      $67.75             EBT
# 13  DOLLAR General         15064   1/19/2023       $3.00             EBT
# 14  DOLLAR General          2840    2/2/2023       $1.82             EBT
# 18  DOLLAR General         15064   1/10/2022      $10.10             EBT
# 20  DOLLAR General         15064  10/30/2022       $3.70             EBT
# 22  DOLLAR General         15064  10/30/2022       $7.05             EBT
# 23  DOLLAR General         15064   10/2/2022       $4.35             EBT
# 25  DOLLAR General         15064   1/21/2023     $128.70             EBT
# 30     DOLLAR TREE          5648  11/19/2022       $5.00             EBT
# 32   FAMILY DOLLAR          3264  11/29/2022       $8.75             EBT
# 33       FOOD CITY           424   12/2/2022      $51.29             EBT
# 34       FOOD CITY           424   2/17/2023      $65.97             EBT
# 46       SAVE ALOT         23488  11/29/2022      $23.10             EBT
# 47       SAVE ALOT         23488    2/2/2023      $45.30             EBT
# 57         WALMART          1233  10/19/2022      $23.20             EBT
# 59         WALMART          1233    1/5/2023      $30.35             EBT
# 62         WALMART          1233  10/12/2022      $35.54             EBT
# 63         WALMART          1233  10/24/2022      $25.38             EBT
# 65         WALMART          1233  10/16/2022     $365.54             EBT
# 67         WALMART          1233   2/17/2023     $157.48             EBT
# 68         WALMART          1233   2/17/2023       $3.48             EBT
# 69         WALMART          1233  10/26/2022      $67.94             EBT
# 71         WALMART          1233  11/18/2022      $76.96             EBT
# 75         WALMART          1233  11/19/2022       $9.25             EBT
#
#    PURCHASE TYPE     STATE
# 0           FOOD  KENTUCKY
# 1           FOOD  KENTUCKY
# 2           FOOD  KENTUCKY
# 4           FOOD  KENTUCKY
# 5           FOOD  KENTUCKY
# 11          FOOD  KENTUCKY
# 12          FOOD  KENTUCKY
# 13          FOOD  KENTUCKY
# 14          FOOD  KENTUCKY
# 18          FOOD  KENTUCKY
# 20          FOOD  KENTUCKY
# 22          FOOD  KENTUCKY
# 23          FOOD  KENTUCKY
# 25          FOOD  KENTUCKY
# 30          FOOD  KENTUCKY
# 32          FOOD  KENTUCKY
# 33          FOOD  KENTUCKY
# 34          FOOD  KENTUCKY
# 46          FOOD  KENTUCKY
# 47          FOOD  KENTUCKY
# 57          FOOD  KENTUCKY
# 59          FOOD  KENTUCKY
# 62          FOOD  KENTUCKY
# 63          FOOD  KENTUCKY
# 65          FOOD  KENTUCKY
# 67          FOOD  KENTUCKY
# 68          FOOD  KENTUCKY
# 69          FOOD  KENTUCKY
# 71          FOOD  KENTUCKY
# 75          FOOD  KENTUCKY
# 1345.7199999999998

# %%
import csv
import pandas as pd
import matplotlib as plt

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(data)




import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()




import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)

Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#         STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022      $14.76             EBT
# 1   DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2   DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3   DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4   DOLLAR General         15064   12/4/2022       $4.25             EBT
# ..             ...           ...         ...          ...            ...
# 76         WALMART          1233  11/19/2022      $12.48            CASH
# 77         WALMART          1233  10/12/2022      $49.00            CASH
# 78         WALMART          3894   9/12/2022      $10.21            CASH
# 79         WALMART          1233  11/19/2022      $49.35            CASH
# 80         WENDY'S         11341   1/12/2023      $32.75            CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1345.7199999999998

# %%
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(walmart_data)
print(Wal_total)
HIBBETTS_data = data.loc[(data['STORE NAME'] == 'HIBBETTS')]
HIBBETTS_total = sum(HIBBETTS_data['AMOUNTS PAID'])
print(HIBBETTS_data)
print(HIBBETTS_total)
VIPFUEL_data = data.loc[(data['STORE NAME'] == 'VIP FUEL')]
VIPFUEL_total = sum(VIPFUEL_data['AMOUNTS PAID'])
print(VIPFUEL_data)
print(VIPFUEL_total)
DOLLARTREE_data = data.loc[(data['STORE NAME'] == 'DOLLAR TREE')]
DOLLARTREE_total = sum(DOLLARTREE_data['AMOUNTS PAID'])
print(DOLLARTREE_data)
print(DOLLARTREE_total)
LOWES_data = data.loc[(data['STORE NAME'] == 'LOWES')]
LOWES_total = sum(LOWES_data['AMOUNTS PAID'])
print(LOWES_data)
print(LOWES_total)
FOODCITY_data = data.loc[(data['STORE NAME'] == 'FOOD CITY')]
FOODCITY_total = sum(FOODCITY_data['AMOUNTS PAID'])
print(FOODCITY_data)
print(FOODCITY_total)
DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(DOLLARGeneral_data)
print(DOLLARGeneral_total)
print(FOODCITY_total)
# Out:
#    STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 56    WALMART          1233   11/9/2022         17.96           CASH
# 57    WALMART          1233  10/19/2022         23.20            EBT
# 58    WALMART          1233  10/21/2022         24.35           CASH
# 59    WALMART          1233    1/5/2023         30.35            EBT
# 60    WALMART          1233  10/21/2022         96.96           CASH
# 61    WALMART          1233  10/17/2022         33.47           CASH
# 62    WALMART          1233  10/12/2022         35.54            EBT
# 63    WALMART          1233  10/24/2022         25.38            EBT
# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)

HIBBETTS_data = data.loc[(data['STORE NAME'] == 'HIBBETTS')]
HIBBETTS_total = sum(HIBBETTS_data['AMOUNTS PAID'])
print(HIBBETTS_data)
print(HIBBETTS_total)
# Out:
#    STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 37   HIBBETTS          1118  11/25/2022         31.80           CASH
# 38   HIBBETTS          1118  11/25/2022        135.62           CASH
#
#    PURCHASE TYPE     STATE
# 37       APPERAL  KENTUCKY
# 38       APPERAL  KENTUCKY
# 167.42000000000002

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(DOLLARGeneral_data)
print(DOLLARGeneral_total)
# Out:
#         STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 1   DOLLAR General         15064  12/26/2022          6.00            EBT
# 2   DOLLAR General         15064   1/23/2023         52.30            EBT
# 3   DOLLAR General         15064  12/21/2022          1.06           CASH
# 4   DOLLAR General         15064   12/4/2022          4.25            EBT
# 5   DOLLAR General         15064  12/29/2022         17.95            EBT
# 6   DOLLAR General         15064  10/30/2022         30.35           CASH
# 7   DOLLAR General         15064  10/26/2022          5.30           CASH
# 8   DOLLAR General         15064   9/27/2022          1.85           CASH
# 9   DOLLAR General         15064  10/22/2022         24.18           CASH
# 10  DOLLAR General         15064  10/21/2022          2.12           CASH
# 11  DOLLAR General         15064   1/19/2023         11.45            EBT
# 12  DOLLAR General         15064   2/17/2023         67.75            EBT
# 13  DOLLAR General         15064   1/19/2023          3.00            EBT
# 14  DOLLAR General          2840    2/2/2023          1.82            EBT
# 15  DOLLAR General          2840    2/2/2023          0.25           CASH
# 16  DOLLAR General         15064   1/11/2023         46.99           CASH
# 17  DOLLAR General         15064    2/2/2023          6.00           CASH
# 18  DOLLAR General         15064   1/10/2022         10.10            EBT
# 19  DOLLAR General         15064  10/16/2022          8.22           CASH
# 20  DOLLAR General         15064  10/30/2022          3.70            EBT
# 21  DOLLAR General         15064  10/30/2022         14.47           CASH
# 22  DOLLAR General         15064  10/30/2022          7.05            EBT
# 23  DOLLAR General         15064   10/2/2022          4.35            EBT
# 24  DOLLAR General         15064   10/2/2022          1.10           CASH
# 25  DOLLAR General         15064   1/21/2023        128.70            EBT
# 26  DOLLAR General         15064   1/11/2023          7.25           CASH
#
#      PURCHASE TYPE     STATE
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# 5             FOOD  KENTUCKY
# 6   KITCHEN SUPPLY  KENTUCKY
# 7         MEDICINE  KENTUCKY
# 8             FOOD  KENTUCKY
# 9      KIDS SUPPLY  KENTUCKY
# 10    HOUSE SUPPLY  KENTUCKY
# 11            FOOD  KENTUCKY
# 12            FOOD  KENTUCKY
# 13            FOOD  KENTUCKY
# 14            FOOD  KENTUCKY
# 15            FOOD  KENTUCKY
# 16            FOOD  KENTUCKY
# 17    HOUSE SUPPLY  KENTUCKY
# 18            FOOD  KENTUCKY
# 19      MOM SUPPLY  KENTUCKY
# 20            FOOD  KENTUCKY
# 21    HOUSE SUPPLY  KENTUCKY
# 22            FOOD  KENTUCKY
# 23            FOOD  KENTUCKY
# 24    HOUSE SUPPLY  KENTUCKY
# 25            FOOD  KENTUCKY
# 26            FOOD  KENTUCKY
# 467.56000000000006

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(DOLLARGeneral_data)
print(DOLLARGeneral_total)
# Out:
#         STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 1   DOLLAR General         15064  12/26/2022          6.00            EBT
# 2   DOLLAR General         15064   1/23/2023         52.30            EBT
# 3   DOLLAR General         15064  12/21/2022          1.06           CASH
# 4   DOLLAR General         15064   12/4/2022          4.25            EBT
# 5   DOLLAR General         15064  12/29/2022         17.95            EBT
# 6   DOLLAR General         15064  10/30/2022         30.35           CASH
# 7   DOLLAR General         15064  10/26/2022          5.30           CASH
# 8   DOLLAR General         15064   9/27/2022          1.85           CASH
# 9   DOLLAR General         15064  10/22/2022         24.18           CASH
# 10  DOLLAR General         15064  10/21/2022          2.12           CASH
# 11  DOLLAR General         15064   1/19/2023         11.45            EBT
# 12  DOLLAR General         15064   2/17/2023         67.75            EBT
# 13  DOLLAR General         15064   1/19/2023          3.00            EBT
# 14  DOLLAR General          2840    2/2/2023          1.82            EBT
# 15  DOLLAR General          2840    2/2/2023          0.25           CASH
# 16  DOLLAR General         15064   1/11/2023         46.99           CASH
# 17  DOLLAR General         15064    2/2/2023          6.00           CASH
# 18  DOLLAR General         15064   1/10/2022         10.10            EBT
# 19  DOLLAR General         15064  10/16/2022          8.22           CASH
# 20  DOLLAR General         15064  10/30/2022          3.70            EBT
# 21  DOLLAR General         15064  10/30/2022         14.47           CASH
# 22  DOLLAR General         15064  10/30/2022          7.05            EBT
# 23  DOLLAR General         15064   10/2/2022          4.35            EBT
# 24  DOLLAR General         15064   10/2/2022          1.10           CASH
# 25  DOLLAR General         15064   1/21/2023        128.70            EBT
# 26  DOLLAR General         15064   1/11/2023          7.25           CASH
#
#      PURCHASE TYPE     STATE
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# 5             FOOD  KENTUCKY
# 6   KITCHEN SUPPLY  KENTUCKY
# 7         MEDICINE  KENTUCKY
# 8             FOOD  KENTUCKY
# 9      KIDS SUPPLY  KENTUCKY
# 10    HOUSE SUPPLY  KENTUCKY
# 11            FOOD  KENTUCKY
# 12            FOOD  KENTUCKY
# 13            FOOD  KENTUCKY
# 14            FOOD  KENTUCKY
# 15            FOOD  KENTUCKY
# 16            FOOD  KENTUCKY
# 17    HOUSE SUPPLY  KENTUCKY
# 18            FOOD  KENTUCKY
# 19      MOM SUPPLY  KENTUCKY
# 20            FOOD  KENTUCKY
# 21    HOUSE SUPPLY  KENTUCKY
# 22            FOOD  KENTUCKY
# 23            FOOD  KENTUCKY
# 24    HOUSE SUPPLY  KENTUCKY
# 25            FOOD  KENTUCKY
# 26            FOOD  KENTUCKY
# 467.56000000000006

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 467.56000000000006

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



FOODCITY_data = data.loc[(data['STORE NAME'] == 'FOOD CITY')]
FOODCITY_total = sum(FOODCITY_data['AMOUNTS PAID'])
print(data.head)
print(FOODCITY_total)
# Out:
# <bound method NDFrame.head of         STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022         14.76            EBT
# 1   DOLLAR General         15064  12/26/2022          6.00            EBT
# 2   DOLLAR General         15064   1/23/2023         52.30            EBT
# 3   DOLLAR General         15064  12/21/2022          1.06           CASH
# 4   DOLLAR General         15064   12/4/2022          4.25            EBT
# ..             ...           ...         ...           ...            ...
# 76         WALMART          1233  11/19/2022         12.48           CASH
# 77         WALMART          1233  10/12/2022         49.00           CASH
# 78         WALMART          3894   9/12/2022         10.21           CASH
# 79         WALMART          1233  11/19/2022         49.35           CASH
# 80         WENDY'S         11341   1/12/2023         32.75           CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]>
# 117.25999999999999

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 467.56000000000006

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


MONEY_GRAM_data = data.loc[(data['STORE NAME'] == 'MONEY GRAM')]
MONEYGRAM_total = sum(MONEY_GRAM_data['AMOUNTS PAID'])
print(data.head()) 
print(MONEYGRAM_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 99.0

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]
EBT_total = sum(EBT_Pay['AMOUNTS PAID'])
print(data)
print(EBT_total)
# Out:
#         STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022         14.76            EBT
# 1   DOLLAR General         15064  12/26/2022          6.00            EBT
# 2   DOLLAR General         15064   1/23/2023         52.30            EBT
# 3   DOLLAR General         15064  12/21/2022          1.06           CASH
# 4   DOLLAR General         15064   12/4/2022          4.25            EBT
# ..             ...           ...         ...           ...            ...
# 76         WALMART          1233  11/19/2022         12.48           CASH
# 77         WALMART          1233  10/12/2022         49.00           CASH
# 78         WALMART          3894   9/12/2022         10.21           CASH
# 79         WALMART          1233  11/19/2022         49.35           CASH
# 80         WENDY'S         11341   1/12/2023         32.75           CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]
# 1327.71

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)

EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]
EBT_total = sum(EBT_Pay['AMOUNTS PAID'])
print(data.head())
print(EBT_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 1327.71

# %%
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]

EBT_total = sum(EBT_Pay['AMOUNTS PAID'])

print(data.head())

print(EBT_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 1327.71

# %%
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


CASH_Pay = data[(data['PAYMENT METHOD'] == 'CASH')]

CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(data.head())

print(CASH_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 1371.6499999999999

# %%
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]

EBT_total = sum(EBT_Pay['AMOUNTS PAID'])

print(EBT_Pay.head())

print(EBT_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
# 5  DOLLAR General         15064  12/29/2022         17.95            EBT
#
#   PURCHASE TYPE     STATE
# 0          FOOD  KENTUCKY
# 1          FOOD  KENTUCKY
# 2          FOOD  KENTUCKY
# 4          FOOD  KENTUCKY
# 5          FOOD  KENTUCKY
# 1327.71

# %%
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


CASH_Pay = data[(data['PAYMENT METHOD'] == 'CASH')]

CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(CASH_Pay.head())

print(CASH_total)
# Out:
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 6  DOLLAR General         15064  10/30/2022         30.35           CASH
# 7  DOLLAR General         15064  10/26/2022          5.30           CASH
# 8  DOLLAR General         15064   9/27/2022          1.85           CASH
# 9  DOLLAR General         15064  10/22/2022         24.18           CASH
#
#     PURCHASE TYPE     STATE
# 3  KITCHEN SUPPLY  KENTUCKY
# 6  KITCHEN SUPPLY  KENTUCKY
# 7        MEDICINE  KENTUCKY
# 8            FOOD  KENTUCKY
# 9     KIDS SUPPLY  KENTUCKY
# 1371.6499999999999

# %%
import csv
import pandas as pd
import matplotlib as plt

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(data.head())

import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

# food city total and first five line
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



FOODCITY_data = data.loc[(data['STORE NAME'] == 'FOOD CITY')]
FOODCITY_total = sum(FOODCITY_data['AMOUNTS PAID'])
print(data.head)
print(FOODCITY_total)

# dollar general total and first five lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)



# Hibbets total and first 5 lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


HIBBETTS_data = data.loc[(data['STORE NAME'] == 'HIBBETTS')]
HIBBETTS_total = sum(HIBBETTS_data['AMOUNTS PAID'])
print(data.head()) 
print(HIBBETTS_total)

# money gram total and first 5 lines

import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


MONEY_GRAM_data = data.loc[(data['STORE NAME'] == 'MONEY GRAM')]
MONEYGRAM_total = sum(MONEY_GRAM_data['AMOUNTS PAID'])
print(data.head()) 
print(MONEYGRAM_total)



# dollar general total and first five lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)




import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()

# ebt payment method total and first five lines
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]

EBT_total = sum(EBT_Pay['AMOUNTS PAID'])

print(EBT_Pay.head())

print(EBT_total)

#cash payment method total and first five lines

import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


CASH_Pay = data[(data['PAYMENT METHOD'] == 'CASH')]

CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(CASH_Pay.head())

print(CASH_total)


import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)



Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1460.20
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#        STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022      $14.76             EBT
# 1  DOLLAR General         15064  12/26/2022       $6.00             EBT
# 2  DOLLAR General         15064   1/23/2023      $52.30             EBT
# 3  DOLLAR General         15064  12/21/2022       $1.06            CASH
# 4  DOLLAR General         15064   12/4/2022       $4.25             EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 2699.36
# <bound method NDFrame.head of         STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0         BIG LOTS           316   10/8/2022         14.76            EBT
# 1   DOLLAR General         15064  12/26/2022          6.00            EBT
# 2   DOLLAR General         15064   1/23/2023         52.30            EBT
# 3   DOLLAR General         15064  12/21/2022          1.06           CASH
# 4   DOLLAR General         15064   12/4/2022          4.25            EBT
# ..             ...           ...         ...           ...            ...
# 76         WALMART          1233  11/19/2022         12.48           CASH
# 77         WALMART          1233  10/12/2022         49.00           CASH
# 78         WALMART          3894   9/12/2022         10.21           CASH
# 79         WALMART          1233  11/19/2022         49.35           CASH
# 80         WENDY'S         11341   1/12/2023         32.75           CASH
#
#      PURCHASE TYPE     STATE
# 0             FOOD  KENTUCKY
# 1             FOOD  KENTUCKY
# 2             FOOD  KENTUCKY
# 3   KITCHEN SUPPLY  KENTUCKY
# 4             FOOD  KENTUCKY
# ..             ...       ...
# 76         APPERAL  KENTUCKY
# 77     WIRE TO RAY  KENTUCKY
# 78            FOOD  KENTUCKY
# 79    HOUSE SUPPLY  KENTUCKY
# 80            FOOD  KENTUCKY
#
# [81 rows x 7 columns]>
# 117.25999999999999
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 467.56000000000006
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 167.42000000000002
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 99.0
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
#
#     PURCHASE TYPE     STATE
# 0            FOOD  KENTUCKY
# 1            FOOD  KENTUCKY
# 2            FOOD  KENTUCKY
# 3  KITCHEN SUPPLY  KENTUCKY
# 4            FOOD  KENTUCKY
# 467.56000000000006
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2022         14.76            EBT
# 1  DOLLAR General         15064  12/26/2022          6.00            EBT
# 2  DOLLAR General         15064   1/23/2023         52.30            EBT
# 4  DOLLAR General         15064   12/4/2022          4.25            EBT
# 5  DOLLAR General         15064  12/29/2022         17.95            EBT
#
#   PURCHASE TYPE     STATE
# 0          FOOD  KENTUCKY
# 1          FOOD  KENTUCKY
# 2          FOOD  KENTUCKY
# 4          FOOD  KENTUCKY
# 5          FOOD  KENTUCKY
# 1327.71
#        STORE NAME  STORE NUMBER        DATE  AMOUNTS PAID PAYMENT METHOD  \
# 3  DOLLAR General         15064  12/21/2022          1.06           CASH
# 6  DOLLAR General         15064  10/30/2022         30.35           CASH
# 7  DOLLAR General         15064  10/26/2022          5.30           CASH
# 8  DOLLAR General         15064   9/27/2022          1.85           CASH
# 9  DOLLAR General         15064  10/22/2022         24.18           CASH
#
#     PURCHASE TYPE     STATE
# 3  KITCHEN SUPPLY  KENTUCKY
# 6  KITCHEN SUPPLY  KENTUCKY
# 7        MEDICINE  KENTUCKY
# 8            FOOD  KENTUCKY
# 9     KIDS SUPPLY  KENTUCKY
# 1371.6499999999999
# 1345.7199999999998

# %%
import csv
import pandas as pd
import matplotlib as plt

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
print(data.head())

import pandas as pd
data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
total = sum(data['AMOUNTS PAID'])
print(total)

# food city total and first five line
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



FOODCITY_data = data.loc[(data['STORE NAME'] == 'FOOD CITY')]
FOODCITY_total = sum(FOODCITY_data['AMOUNTS PAID'])
print(data.head)
print(FOODCITY_total)

# dollar general total and first five lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)



# Hibbets total and first 5 lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


HIBBETTS_data = data.loc[(data['STORE NAME'] == 'HIBBETTS')]
HIBBETTS_total = sum(HIBBETTS_data['AMOUNTS PAID'])
print(data.head()) 
print(HIBBETTS_total)

# money gram total and first 5 lines

import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


MONEY_GRAM_data = data.loc[(data['STORE NAME'] == 'MONEY GRAM')]
MONEYGRAM_total = sum(MONEY_GRAM_data['AMOUNTS PAID'])
print(data.head()) 
print(MONEYGRAM_total)



# dollar general total and first five lines
import pandas as pd

data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')

data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)



DOLLARGeneral_data = data.loc[(data['STORE NAME'] == 'DOLLAR General')]
DOLLARGeneral_total = sum(DOLLARGeneral_data['AMOUNTS PAID'])
print(data.head()) 
print(DOLLARGeneral_total)




import matplotlib.pyplot as plt
labels = 'WALMART', 'DOLLAR GENERAL', 'HIBBETTS', 'FOOD CITY', 'MONEY GRAM'
sizes = [1345.72, 467.00, 167.42, 117.26, 99.00]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()

# ebt payment method total and first five lines
import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


EBT_Pay = data[(data['PAYMENT METHOD'] == 'EBT')]

EBT_total = sum(EBT_Pay['AMOUNTS PAID'])

print(EBT_Pay.head())

print(EBT_total)

#cash payment method total and first five lines

import pandas as pd


data = pd.read_csv(r'C:\Users\shede\OneDrive\Desktop\git\data_1_checks.py\ASSETS\FAMILY FINANCES SINCE 0801222.csv')


data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)


CASH_Pay = data[(data['PAYMENT METHOD'] == 'CASH')]

CASH_total = sum(CASH_Pay['AMOUNTS PAID'])

print(CASH_Pay.head())

print(CASH_total)


import matplotlib.pyplot as plt
labels = 'CASH', 'EBT'
sizes = [1371.65, 1327.71]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.show()


# wal total
data[data.columns[3]] = data[data.columns[3]].replace('[\$,]', '', regex=True).astype(float)
walmart_data = data.loc[(data['STORE NAME'] == 'WALMART')]
Wal_total = sum(walmart_data['AMOUNTS PAID'])
print(Wal_total)



Item_names = ['FOOD', 'HOUSE HOLD', 'Apperal']
Items_counts = [1345.71
, 343.49, 277.00]

fig, ax = plt.subplots()
bar_container = ax.bar(Item_names, Items_counts)
ax.set(ylabel='Money Spent', title='Walmart Sales', ylim=(0, 2000))
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()
# Out:
#        STORE NAME  STORE NUMBER        DATE AMOUNTS PAID PAYMENT METHOD  \
# 0        BIG LOTS           316   10/8/2